# %%
import pandas as pd

# %%
movies_data = pd.read_csv("tmdb_5000_movies.csv",)

# %%
movies_data
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
type(movies_data)
# Out:
# pandas.core.frame.DataFrame

# %%
movies_data.shape
# Out:
# (4803, 20)

# %%
movies_data.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
movies_data.index
# Out:
# RangeIndex(start=0, stop=4803, step=1)

# %%
movies_data.head(10)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5  258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6  260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7  280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8  250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9  250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             homepage      id  \
# 0                        http://www.avatarmovie.com/   19995
# 1       http://disney.go.com/disneypictures/pirates/     285
# 2        http://www.sonypictures.com/movies/spectre/  206647
# ...

# %%
movies_data.tail(10)
# Out:
#       budget                                             genres  \
# 4793       0                      [{"id": 18, "name": "Drama"}]
# 4794       0  [{"id": 53, "name": "Thriller"}, {"id": 27, "n...
# 4795       0                      [{"id": 18, "name": "Drama"}]
# 4796    7000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 4797       0  [{"id": 10769, "name": "Foreign"}, {"id": 53, ...
# 4798  220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799    9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800       0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801       0                                                 []
# 4802       0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 4793                                                NaN  182291
# 4794                                                NaN  286939
# 4795                                                NaN  124606
# ...

# %%
movies_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
movies_data.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# ...

# %%
movies_data.head(5)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies_data['budget']
# Out:
# 0       237000000
# 1       300000000
# 2       245000000
# 3       250000000
# 4       260000000
#           ...
# 4798       220000
# 4799         9000
# 4800            0
# 4801            0
# 4802            0
# Name: budget, Length: 4803, dtype: int64

# %%
movies_data[['budget', 'original_title']]
# Out:
#          budget                            original_title
# 0     237000000                                    Avatar
# 1     300000000  Pirates of the Caribbean: At World's End
# 2     245000000                                   Spectre
# 3     250000000                     The Dark Knight Rises
# 4     260000000                               John Carter
# ...         ...                                       ...
# 4798     220000                               El Mariachi
# 4799       9000                                 Newlyweds
# 4800          0                 Signed, Sealed, Delivered
# 4801          0                          Shanghai Calling
# 4802          0                         My Date with Drew
#
# [4803 rows x 2 columns]

# %%
type(movies_data[['budget', 'original_title']])
# Out:
# pandas.core.frame.DataFrame

# %%
type(movies_data['budget'])
# Out:
# pandas.core.series.Series

# %%
movies_data[0:1]
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
# ...

# %%
movies_data[5:10]
# Out:
#       budget                                             genres  \
# 5  258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6  260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7  280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8  250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9  250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             homepage      id  \
# 5    http://www.sonypictures.com/movies/spider-man3/     559
# 6       http://disney.go.com/disneypictures/tangled/   38757
# 7  http://marvel.com/movies/movie/193/avengers_ag...   99861
# 8  http://harrypotter.warnerbros.com/harrypottera...     767
# 9       http://www.batmanvsupermandawnofjustice.com/  209112
#
#                                             keywords original_language  \
# 5  [{"id": 851, "name": "dual identity"}, {"id": ...                en
# ...

# %%
movies_data.iloc[5]
# Out:
# budget                                                          258000000
# genres                  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# homepage                  http://www.sonypictures.com/movies/spider-man3/
# id                                                                    559
# keywords                [{"id": 851, "name": "dual identity"}, {"id": ...
# original_language                                                      en
# original_title                                               Spider-Man 3
# overview                The seemingly invincible Spider-Man goes up ag...
# popularity                                                     115.699814
# production_companies    [{"name": "Columbia Pictures", "id": 5}, {"nam...
# production_countries    [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                   2007-05-01
# revenue                                                         890871626
# ...

# %%
type(movies_data.iloc[0])
# Out:
# pandas.core.series.Series

# %%
movies_data.iloc[5:15]
# Out:
#        budget                                             genres  \
# 5   258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6   260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7   280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8   250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9   250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 10  270000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 11  200000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 12  200000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 13  255000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 14  225000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                              homepage      id  \
# 5     http://www.sonypictures.com/movies/spider-man3/     559
# 6        http://disney.go.com/disneypictures/tangled/   38757
# ...

# %%
type(movies_data.iloc[2:5])
# Out:
# pandas.core.frame.DataFrame

# %%
movies_data.iloc[[0,5,7,10]]
# Out:
#        budget                                             genres  \
# 0   237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5   258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 7   280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 10  270000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                              homepage     id  \
# 0                         http://www.avatarmovie.com/  19995
# 5     http://www.sonypictures.com/movies/spider-man3/    559
# 7   http://marvel.com/movies/movie/193/avengers_ag...  99861
# 10                            http://www.superman.com   1452
#
#                                              keywords original_language  \
# 0   [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 5   [{"id": 851, "name": "dual identity"}, {"id": ...                en
# 7   [{"id": 8828, "name": "marvel comic"}, {"id": ...                en
# ...

# %%
movies_data.iloc[1:5, [2,3,4]]
# Out:
#                                        homepage      id  \
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...
# 4  [{"id": 818, "name": "based on novel"}, {"id":...

# %%
movies_data.iloc[1:5, 1:5]
# Out:
#                                               genres  \
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...
# 4  [{"id": 818, "name": "based on novel"}, {"id":...

# %%
movies_data.loc[1:5]
# Out:
#       budget                                             genres  \
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5  258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
#
#                                           homepage      id  \
# 1     http://disney.go.com/disneypictures/pirates/     285
# 2      http://www.sonypictures.com/movies/spectre/  206647
# 3               http://www.thedarkknightrises.com/   49026
# 4             http://movies.disney.com/john-carter   49529
# 5  http://www.sonypictures.com/movies/spider-man3/     559
#
#                                             keywords original_language  \
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# ...

# %%
movies= pd.read_csv("tmdb_5000_movies.csv", index_col = "original_title")
movies
# Out:
#                                              budget  \
# original_title
# Avatar                                    237000000
# Pirates of the Caribbean: At World's End  300000000
# Spectre                                   245000000
# The Dark Knight Rises                     250000000
# John Carter                               260000000
# ...                                             ...
# El Mariachi                                  220000
# Newlyweds                                      9000
# Signed, Sealed, Delivered                         0
# Shanghai Calling                                  0
# My Date with Drew                                 0
#
#                                                                                      genres  \
# original_title
# Avatar                                    [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# Pirates of the Caribbean: At World's End  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# ...

# %%
movies.loc[['Avatar','John Carter']]
# Out:
#                    budget                                             genres  \
# original_title
# Avatar          237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# John Carter     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             homepage     id  \
# original_title
# Avatar                   http://www.avatarmovie.com/  19995
# John Carter     http://movies.disney.com/john-carter  49529
#
#                                                          keywords  \
# original_title
# Avatar          [{"id": 1463, "name": "culture clash"}, {"id":...
# John Carter     [{"id": 818, "name": "based on novel"}, {"id":...
#
#                original_language  \
# original_title
# Avatar                        en
# John Carter                   en
#
#                                                          overview  popularity  \
# original_title
# Avatar          In the 22nd century, a paraplegic Marine is di...  150.437577
# ...

# %%
movies.loc[['Avatar','John Carter'], ['genres']]
# Out:
#                                                            genres
# original_title
# Avatar          [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# John Carter     [{"id": 28, "name": "Action"}, {"id": 12, "nam...

# %%
ser = movies_data["budget"]
ser
# Out:
# 0       237000000
# 1       300000000
# 2       245000000
# 3       250000000
# 4       260000000
#           ...
# 4798       220000
# 4799         9000
# 4800            0
# 4801            0
# 4802            0
# Name: budget, Length: 4803, dtype: int64

# %%
ser.dtype
# Out:
# dtype('int64')

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
ser.sum()
# Out:
# 139503326521

# %%
ser.size
# Out:
# 4803

# %%
ser.shape
# Out:
# (4803,)

# %%
ser.describe
# Out:
# <bound method NDFrame.describe of 0       237000000
# 1       300000000
# 2       245000000
# 3       250000000
# 4       260000000
#           ...
# 4798       220000
# 4799         9000
# 4800            0
# 4801            0
# 4802            0
# Name: budget, Length: 4803, dtype: int64>

# %%
ser.count()
# Out:
# 4803

# %%
ser.mean()
# Out:
# 29045039.87528628

# %%
ser.median()
# Out:
# 15000000.0

# %%
ser.max()
# Out:
# 380000000

# %%
ser.min()
# Out:
# 0

# %%
ser.unique()
# Out:
# array([237000000, 300000000, 245000000, 250000000, 260000000, 258000000,
#        280000000, 270000000, 200000000, 255000000, 225000000, 220000000,
#        380000000, 215000000, 180000000, 207000000, 209000000, 150000000,
#        210000000, 170000000, 190000000, 195000000, 105000000, 185000000,
#        175000000, 140000000, 176000003, 178000000, 145000000,  27000000,
#        165000000, 160000000,  15000000,  38000000, 155000000, 149000000,
#        144000000,  70000000, 100000000, 139000000, 135000000, 130000000,
#        137000000, 120000000, 132000000, 110000000, 125000000, 127500000,
#        127000000, 103000000,  65000000, 123000000, 115000000, 117000000,
#        113000000,  97250400, 116000000, 112000000,  93000000, 107000000,
#                0, 133000000, 108000000, 126000000,  90000000, 102000000,
#         80000000,  84000000,  99000000,  10000000,  98000000,  94000000,
#         85000000,  92000000,  95000000,  79000000,  75000000,  88000000,
# ...

# %%
ser.nunique()
# Out:
# 436

# %%
len(ser.unique())
# Out:
# 436

# %%
ser.nunique(dropna = False)
# Out:
# 436

# %%
#only data-frame = .info
#only series = .unique .value_count

# %%
ser.value_counts()
# Out:
# 0           1037
# 20000000     144
# 30000000     128
# 25000000     126
# 40000000     123
#             ...
# 13200000       1
# 14350531       1
# 3100000        1
# 12800000       1
# 9000           1
# Name: budget, Length: 436, dtype: int64

# %%
ser.value_counts(ascending =True,bins = 3)
# Out:
# (253333333.333, 380000000.0]         8
# (126666666.667, 253333333.333]     196
# (-380000.001, 126666666.667]      4599
# Name: budget, dtype: int64

# %%
anime = ["hello", "Abhishek", "how" , "are", "you"]
series = pd.Series(anime , name="anime genre")
series
# Out:
# 0       hello
# 1    Abhishek
# 2         how
# 3         are
# 4         you
# Name: anime genre, dtype: object

# %%
anime = ["hello", "Abhishek", "how" , "are", "you"] #this could be numpy array
genre =[1,2,3,4,5]
series2 = pd.Series(genre , index=anime, name = "series12")
series2
# Out:
# hello       1
# Abhishek    2
# how         3
# are         4
# you         5
# Name: series12, dtype: int64

# %%
dictionary = {
    'hello'      : 1,
    'Abhishek'   : 2,
    'how'        : 3,
   ' are  '      : 4,
    'you'        : 5
}
seri = pd.Series(dictionary)

# %%
seri
# Out:
# hello       1
# Abhishek    2
# how         3
#  are        4
# you         5
# dtype: int64

# %%
movie = pd.read_csv("tmdb_5000_movies.csv",usecols = ['runtime', 'genres'], squeeze =True)
movie
# Out:
#                                                  genres  runtime
# 0     [{"id": 28, "name": "Action"}, {"id": 12, "nam...    162.0
# 1     [{"id": 12, "name": "Adventure"}, {"id": 14, "...    169.0
# 2     [{"id": 28, "name": "Action"}, {"id": 12, "nam...    148.0
# 3     [{"id": 28, "name": "Action"}, {"id": 80, "nam...    165.0
# 4     [{"id": 28, "name": "Action"}, {"id": 12, "nam...    132.0
# ...                                                 ...      ...
# 4798  [{"id": 28, "name": "Action"}, {"id": 80, "nam...     81.0
# 4799  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...     85.0
# 4800  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...    120.0
# 4801                                                 []     98.0
# 4802                [{"id": 99, "name": "Documentary"}]     90.0
#
# [4803 rows x 2 columns]

# %%
seri.sort_index()
# Out:
#  are        4
# Abhishek    2
# hello       1
# how         3
# you         5
# dtype: int64

# %%
seri.sort_index(ascending=False , inplace=True)

# %%
seri
# Out:
# you         5
# how         3
# hello       1
# Abhishek    2
#  are        4
# dtype: int64

# %%
seri.sort_values()
# Out:
# hello       1
# Abhishek    2
# how         3
#  are        4
# you         5
# dtype: int64

# %%
listis= seri.tolist()
print(listis)
seri.values
# Out:
# [5, 3, 1, 2, 4]
# array([5, 3, 1, 2, 4], dtype=int64)

# %%
seri.nsmallest(n=1)
# Out:
# hello    1
# dtype: int64

# %%
seri.nsmallest().index[0]
# Out:
# 'hello'

# %%
#nlargest

# %%
seri.idxmin()
# Out:
# 'hello'

# %%
seri.idxmax()
# Out:
# 'you'

# %%
seri.reset_index()
# Out:
#       index  0
# 0       you  5
# 1       how  3
# 2     hello  1
# 3  Abhishek  2
# 4     are    4

# %%
movies.set_index('genres')
# Out:
#                                                        budget  \
# genres
# [{"id": 28, "name": "Action"}, {"id": 12, "name...  237000000
# [{"id": 12, "name": "Adventure"}, {"id": 14, "n...  300000000
# [{"id": 28, "name": "Action"}, {"id": 12, "name...  245000000
# [{"id": 28, "name": "Action"}, {"id": 80, "name...  250000000
# [{"id": 28, "name": "Action"}, {"id": 12, "name...  260000000
# ...                                                       ...
# [{"id": 28, "name": "Action"}, {"id": 80, "name...     220000
# [{"id": 35, "name": "Comedy"}, {"id": 10749, "n...       9000
# [{"id": 35, "name": "Comedy"}, {"id": 18, "name...          0
# []                                                          0
# [{"id": 99, "name": "Documentary"}]                         0
#
#                                                                                              homepage  \
# genres
# ...

# %%
movies.index
# Out:
# Index(['Avatar', 'Pirates of the Caribbean: At World's End', 'Spectre',
#        'The Dark Knight Rises', 'John Carter', 'Spider-Man 3', 'Tangled',
#        'Avengers: Age of Ultron', 'Harry Potter and the Half-Blood Prince',
#        'Batman v Superman: Dawn of Justice',
#        ...
#        'On The Downlow', 'Sanctuary: Quite a Conundrum', 'Bang', 'Primer',
#        'Cavite', 'El Mariachi', 'Newlyweds', 'Signed, Sealed, Delivered',
#        'Shanghai Calling', 'My Date with Drew'],
#       dtype='object', name='original_title', length=4803)

# %%
movies.index[-2:]
# Out:
# Index(['Shanghai Calling', 'My Date with Drew'], dtype='object', name='original_title')

# %%
movies.columns.get_loc("genres") #.is_unique
# Out:
# 1

# %%
 movies_data[movies_data.original_title == 'Avatar']
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
# ...
