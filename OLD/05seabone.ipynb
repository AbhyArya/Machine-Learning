# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset("iris")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df["sepal_length"], df["petal_length"])

# %%
plt.scatter(df["sepal_length"], df["petal_length"])
sns.set()
plt.show()

# %%
plt.scatter(df["sepal_length"], df["petal_length"])
sns.set_style('darkgrid', {"grid.color":".9"})
sns.despine()
plt.show()

# %%
sns.palplot(sns.color_palette("dark", 10))

# %%
sns.relplot(data=df, x = "sepal_length", y = "petal_length", hue="species")

# %%
sns.relplot(data=df, x = "sepal_length", y = "petal_length",kind="line", hue="species")

# %%
sns.displot(df['sepal_length'], kde = False)

# %%
sns.barplot(data = df, x='species', y = 'petal_length', ci=None , )
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
sns.barplot(data = df, x='petal_length', y = 'species', ci=None  ,orient='h')
plt.show()

# %%
 df2 = sns.load_dataset('titanic')

# %%
df2.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.countplot(data=df2, x="class", hue='who', palette = 'magma')
plt.title("passenger")
# Out:
# Text(0.5, 1.0, 'passenger')

# %%
sns.kdeplot(df[df['species']=='setosa']['sepal_length'], df['sepal_width'], color='r', shade = True,cmap ="Reds")
sns.kdeplot(df[df['species']=='versicolor']['sepal_length'], df['sepal_width'], color='b', shade = True,cmap ="Blues")
# Out:
# C:\Users\Abhi Arya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Abhi Arya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.boxplot(data=df2, x='class', y='fare')
# Out:
# <AxesSubplot:xlabel='class', ylabel='fare'>

# %%
df3 = sns.load_dataset("flights")
df3 = df3.pivot('month', 'year', 'passengers')
sns.heatmap(df3)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.pairplot(df, hue='species', kind='scatter')
